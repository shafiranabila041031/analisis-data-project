# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Shafira Nabila Noer Poerwanto
# - **Email:** cdcc284d6x2715@student.devacademy.id
# - **ID Dicoding:** shafiranabila096

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana tren pertumbuhan total penyewaan sepeda secara bulanan (Month-over-Month) sepanjang tahun 2012 jika dibandingkan dengan tahun 2011, guna merencanakan target penambahan kapasitas armada sepeda di tahun depan?
# - Pertanyaan 2: Pada jam berapakah rata-rata volume penyewaan sepeda mencapai puncaknya (rush hour) khusus pada hari kerja (workingday) selama Kuartal ke-4 (Bulan Oktober - Desember) tahun 2012, agar tim operasional dapat menetapkan jadwal maintenance rutin tanpa mengganggu pelanggan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df=pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df=pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Dataset day_df berisi data penyewaan sepeda dengan granularitas harian, sehingga setiap baris merepresentasikan satu hari. Dataset ini memuat informasi waktu seperti musim, tahun, bulan, hari libur, hari kerja, serta kondisi cuaca seperti suhu, kelembapan, dan kecepatan angin. Selain itu, terdapat variabel utama berupa jumlah pengguna casual, registered, dan total penyewaan (cnt) yang menjadi indikator utama performa bisnis harian.
# - Dataset hour_df memiliki struktur kolom yang hampir sama dengan day_df, namun dengan tingkat detail yang lebih tinggi karena setiap baris merepresentasikan data per jam. Hal ini ditunjukkan dengan adanya kolom tambahan hr yang menunjukkan jam penyewaan dari 0 hingga 23. Dataset ini sangat berguna untuk menganalisis pola penggunaan sepeda secara intrahari, seperti identifikasi jam sibuk, perilaku komuter, dan fluktuasi permintaan sepanjang hari.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Data `day_df`

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Data `hour_df`

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# **Insight:**
# - Dataset memiliki kualitas yang baik karena tidak terdapat missing values dan duplikasi, sehingga data dapat langsung digunakan tanpa proses pembersihan yang kompleks
# - Variabel dalam dataset didominasi oleh tipe numerik, yang memudahkan proses analisis statistik maupun pemodelan, namun kolom tanggal masih perlu dikonversi agar analisis berbasis waktu lebih maksimal
# - Tersedianya dua level data yaitu harian dan per jam memberikan fleksibilitas analisis, sehingga pola permintaan dapat dikaji baik secara umum maupun lebih detail berdasarkan waktu

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Data `day_df`

# %% [markdown]
# ##### Menghapus Data duplikat

# %%
day_df.duplicated().sum()
day_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menghapus Missing values

# %%
day_df = hour_df.dropna()
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ##### Menghapus kolom 'instant' karena hanya berupa nomor urut

# %%
day_df.drop('instant', axis=1, inplace=True)

# %% [markdown]
# ##### Mengubah tipe data 'dteday' menjadi datetime

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])

# %% [markdown]
# ##### Melabeli Ulang Data (Mapping Kategori)

# %%
season_mapping = {1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'}
weekday_mapping = {0: 'Minggu', 1: 'Senin', 2: 'Selasa', 3: 'Rabu', 4: 'Kamis', 5: 'Jumat', 6: 'Sabtu'}
weather_mapping = {1: 'Cerah/Sebagian Berawan', 2: 'Kabut/Berawan', 3: 'Salju Ringan/Hujan', 4: 'Hujan Lebat/Badai'}

day_df['season'] = day_df['season'].map(season_mapping)
day_df['weekday'] = day_df['weekday'].map(weekday_mapping)
day_df['weathersit'] = day_df['weathersit'].map(weather_mapping)

# %% [markdown]
# ##### Membuat kolom 'day_type' (Hari Kerja vs Libur)

# %%
day_df['day_type'] = day_df['workingday'].apply(lambda x: 'Hari Kerja' if x == 1 else 'Akhir Pekan/Libur')

# %% [markdown]
# ##### Mengubah Format Tanggal menjadi DD-MM-YYYY

# %%
# day_df['dteday'] = day_df['dteday'].dt.strftime('%d-%m-%Y')

# %% [markdown]
# ##### Ekstraksi tahun dan bulan untuk mempermudah filter Time-bound

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
day_df['year'] = day_df['dteday'].dt.year
day_df['month'] = day_df['dteday'].dt.month

# %% [markdown]
# ##### Menampilkan data

# %%
day_df.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0 2011-01-01  Spring   0     1   0        0   Sabtu           0
# 1 2011-01-01  Spring   0     1   1        0   Sabtu           0
# 2 2011-01-01  Spring   0     1   2        0   Sabtu           0
# 3 2011-01-01  Spring   0     1   3        0   Sabtu           0
# 4 2011-01-01  Spring   0     1   4        0   Sabtu           0
#
#                weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0  Cerah/Sebagian Berawan  0.24  0.2879  0.81        0.0       3          13
# 1  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       8          32
# 2  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       5          27
# 3  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       3          10
# 4  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       0           1
#
#    cnt           day_type  year  month
# 0   16  Akhir Pekan/Libur  2011      1
# 1   40  Akhir Pekan/Libur  2011      1
# 2   32  Akhir Pekan/Libur  2011      1
# 3   13  Akhir Pekan/Libur  2011      1
# 4    1  Akhir Pekan/Libur  2011      1

# %% [markdown]
# #### Data `hour_df`

# %% [markdown]
# ##### Mengahapus data duplikat

# %%
hour_df.duplicated().sum()
hour_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menghapus Missing values

# %%
hour_df = hour_df.dropna()
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ##### Menghapus kolom 'instant' karena hanya berupa nomor urut

# %%
hour_df.drop('instant', axis=1, inplace=True)

# %% [markdown]
# ##### Mengubah tipe data 'dteday' menjadi datetime

# %%
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %% [markdown]
# ##### Melabeli Ulang Data (Mapping Kategori)

# %%
season_mapping = {1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'}
weekday_mapping = {0: 'Minggu', 1: 'Senin', 2: 'Selasa', 3: 'Rabu', 4: 'Kamis', 5: 'Jumat', 6: 'Sabtu'}
weather_mapping = {1: 'Cerah/Sebagian Berawan', 2: 'Kabut/Berawan', 3: 'Salju Ringan/Hujan', 4: 'Hujan Lebat/Badai'}

hour_df['season'] = hour_df['season'].map(season_mapping)
hour_df['weekday'] = hour_df['weekday'].map(weekday_mapping)
hour_df['weathersit'] = hour_df['weathersit'].map(weather_mapping)

# %% [markdown]
# ##### Membuat kolom 'day_type' (Hari Kerja vs Libur)

# %%
hour_df['day_type'] = hour_df['workingday'].apply(lambda x: 'Hari Kerja' if x == 1 else 'Akhir Pekan/Libur')

# %% [markdown]
# ##### Ekstraksi tahun dan bulan untuk mempermudah filter Time-bound

# %%
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])
hour_df['year'] = hour_df['dteday'].dt.year
hour_df['month'] = hour_df['dteday'].dt.month

# %% [markdown]
# ##### Menampilkan data

# %%
hour_df.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0 2011-01-01  Spring   0     1   0        0   Sabtu           0
# 1 2011-01-01  Spring   0     1   1        0   Sabtu           0
# 2 2011-01-01  Spring   0     1   2        0   Sabtu           0
# 3 2011-01-01  Spring   0     1   3        0   Sabtu           0
# 4 2011-01-01  Spring   0     1   4        0   Sabtu           0
#
#                weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0  Cerah/Sebagian Berawan  0.24  0.2879  0.81        0.0       3          13
# 1  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       8          32
# 2  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       5          27
# 3  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       3          10
# 4  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       0           1
#
#    cnt           day_type  year  month
# 0   16  Akhir Pekan/Libur  2011      1
# 1   40  Akhir Pekan/Libur  2011      1
# 2   32  Akhir Pekan/Libur  2011      1
# 3   13  Akhir Pekan/Libur  2011      1
# 4    1  Akhir Pekan/Libur  2011      1

# %% [markdown]
# **Insight:**
# - Data `day_df`: Data harian menjadi lebih bersih dan konsisten setelah penghapusan duplikasi, missing values, dan kolom yang tidak relevan. Selain itu, pelabelan ulang kategori, perubahan format tanggal, serta penambahan kolom day_type membuat data lebih mudah dipahami dan siap untuk analisis pola harian.
# - Data `hour_df`: Data per jam juga menjadi lebih rapi dan terstruktur setelah proses cleaning yang sama, sehingga setiap jam pengamatan lebih akurat. Penyesuaian format tanggal, relabeling, dan penambahan day_type membantu analisis yang lebih detail berdasarkan waktu dan jenis hari.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df

# %%
day_df.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0 2011-01-01  Spring   0     1   0        0   Sabtu           0
# 1 2011-01-01  Spring   0     1   1        0   Sabtu           0
# 2 2011-01-01  Spring   0     1   2        0   Sabtu           0
# 3 2011-01-01  Spring   0     1   3        0   Sabtu           0
# 4 2011-01-01  Spring   0     1   4        0   Sabtu           0
#
#                weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0  Cerah/Sebagian Berawan  0.24  0.2879  0.81        0.0       3          13
# 1  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       8          32
# 2  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       5          27
# 3  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       3          10
# 4  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       0           1
#
#    cnt           day_type  year  month demand_category
# 0   16  Akhir Pekan/Libur  2011      1      Low Demand
# 1   40  Akhir Pekan/Libur  2011      1      Low Demand
# 2   32  Akhir Pekan/Libur  2011      1      Low Demand
# 3   13  Akhir Pekan/Libur  2011      1      Low Demand
# 4    1  Akhir Pekan/Libur  2011      1      Low Demand

# %%
day_df.describe(include='all')
# Out:
#                                dteday season            yr          mnth  \
# count                           17379  17379  17379.000000  17379.000000
# unique                            NaN      4           NaN           NaN
# top                               NaN   Fall           NaN           NaN
# freq                              NaN   4496           NaN           NaN
# mean    2012-01-02 04:08:34.552045568    NaN      0.502561      6.537775
# min               2011-01-01 00:00:00    NaN      0.000000      1.000000
# 25%               2011-07-04 00:00:00    NaN      0.000000      4.000000
# 50%               2012-01-02 00:00:00    NaN      1.000000      7.000000
# 75%               2012-07-02 00:00:00    NaN      1.000000     10.000000
# max               2012-12-31 00:00:00    NaN      1.000000     12.000000
# std                               NaN    NaN      0.500008      3.438776
#
#                   hr       holiday weekday    workingday  \
# count   17379.000000  17379.000000   17379  17379.000000
# unique           NaN           NaN       7           NaN
# top              NaN           NaN   Sabtu           NaN
# freq             NaN           NaN    2512           NaN
# mean       11.546752      0.028770     NaN      0.682721
# min         0.000000      0.000000     NaN      0.000000
# 25%         6.000000      0.000000     NaN      0.000000
# 50%        12.000000      0.000000     NaN      1.000000
# 75%        18.000000      0.000000     NaN      1.000000
# max        23.000000      1.000000     NaN      1.000000
# std         6.914405      0.167165     NaN      0.465431
#
#                     weathersit          temp         atemp           hum  \
# count                    17379  17379.000000  17379.000000  17379.000000
# unique                       4           NaN           NaN           NaN
# top     Cerah/Sebagian Berawan           NaN           NaN           NaN
# freq                     11413           NaN           NaN           NaN
# mean                       NaN      0.496987      0.475775      0.627229
# min                        NaN      0.020000      0.000000      0.000000
# 25%                        NaN      0.340000      0.333300      0.480000
# 50%                        NaN      0.500000      0.484800      0.630000
# 75%                        NaN      0.660000      0.621200      0.780000
# max                        NaN      1.000000      1.000000      1.000000
# std                        NaN      0.192556      0.171850      0.192930
#
#            windspeed        casual    registered           cnt    day_type  \
# count   17379.000000  17379.000000  17379.000000  17379.000000       17379
# unique           NaN           NaN           NaN           NaN           2
# top              NaN           NaN           NaN           NaN  Hari Kerja
# freq             NaN           NaN           NaN           NaN       11865
# mean        0.190098     35.676218    153.786869    189.463088         NaN
# min         0.000000      0.000000      0.000000      1.000000         NaN
# 25%         0.104500      4.000000     34.000000     40.000000         NaN
# 50%         0.194000     17.000000    115.000000    142.000000         NaN
# 75%         0.253700     48.000000    220.000000    281.000000         NaN
# max         0.850700    367.000000    886.000000    977.000000         NaN
# std         0.122340     49.305030    151.357286    181.387599         NaN
#
#                 year         month demand_category
# count   17379.000000  17379.000000           17379
# unique           NaN           NaN               3
# top              NaN           NaN   Medium Demand
# freq             NaN           NaN            5823
# mean     2011.502561      6.537775             NaN
# min      2011.000000      1.000000             NaN
# 25%      2011.000000      4.000000             NaN
# 50%      2012.000000      7.000000             NaN
# 75%      2012.000000     10.000000             NaN
# max      2012.000000     12.000000             NaN
# std         0.500008      3.438776             NaN

# %%
day_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17374    False
# 17375    False
# 17376    False
# 17377    False
# 17378    False
# Length: 17379, dtype: bool

# %% [markdown]
# ### Explore hour_df

# %%
hour_df.head()
# Out:
#       dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0 2011-01-01  Spring   0     1   0        0   Sabtu           0
# 1 2011-01-01  Spring   0     1   1        0   Sabtu           0
# 2 2011-01-01  Spring   0     1   2        0   Sabtu           0
# 3 2011-01-01  Spring   0     1   3        0   Sabtu           0
# 4 2011-01-01  Spring   0     1   4        0   Sabtu           0
#
#                weathersit  temp   atemp   hum  windspeed  casual  registered  \
# 0  Cerah/Sebagian Berawan  0.24  0.2879  0.81        0.0       3          13
# 1  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       8          32
# 2  Cerah/Sebagian Berawan  0.22  0.2727  0.80        0.0       5          27
# 3  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       3          10
# 4  Cerah/Sebagian Berawan  0.24  0.2879  0.75        0.0       0           1
#
#    cnt           day_type  year  month
# 0   16  Akhir Pekan/Libur  2011      1
# 1   40  Akhir Pekan/Libur  2011      1
# 2   32  Akhir Pekan/Libur  2011      1
# 3   13  Akhir Pekan/Libur  2011      1
# 4    1  Akhir Pekan/Libur  2011      1

# %%
hour_df.describe(include='all')
# Out:
#                                dteday season            yr          mnth  \
# count                           17379  17379  17379.000000  17379.000000
# unique                            NaN      4           NaN           NaN
# top                               NaN   Fall           NaN           NaN
# freq                              NaN   4496           NaN           NaN
# mean    2012-01-02 04:08:34.552045568    NaN      0.502561      6.537775
# min               2011-01-01 00:00:00    NaN      0.000000      1.000000
# 25%               2011-07-04 00:00:00    NaN      0.000000      4.000000
# 50%               2012-01-02 00:00:00    NaN      1.000000      7.000000
# 75%               2012-07-02 00:00:00    NaN      1.000000     10.000000
# max               2012-12-31 00:00:00    NaN      1.000000     12.000000
# std                               NaN    NaN      0.500008      3.438776
#
#                   hr       holiday weekday    workingday  \
# count   17379.000000  17379.000000   17379  17379.000000
# unique           NaN           NaN       7           NaN
# top              NaN           NaN   Sabtu           NaN
# freq             NaN           NaN    2512           NaN
# mean       11.546752      0.028770     NaN      0.682721
# min         0.000000      0.000000     NaN      0.000000
# 25%         6.000000      0.000000     NaN      0.000000
# 50%        12.000000      0.000000     NaN      1.000000
# 75%        18.000000      0.000000     NaN      1.000000
# max        23.000000      1.000000     NaN      1.000000
# std         6.914405      0.167165     NaN      0.465431
#
#                     weathersit          temp         atemp           hum  \
# count                    17379  17379.000000  17379.000000  17379.000000
# unique                       4           NaN           NaN           NaN
# top     Cerah/Sebagian Berawan           NaN           NaN           NaN
# freq                     11413           NaN           NaN           NaN
# mean                       NaN      0.496987      0.475775      0.627229
# min                        NaN      0.020000      0.000000      0.000000
# 25%                        NaN      0.340000      0.333300      0.480000
# 50%                        NaN      0.500000      0.484800      0.630000
# 75%                        NaN      0.660000      0.621200      0.780000
# max                        NaN      1.000000      1.000000      1.000000
# std                        NaN      0.192556      0.171850      0.192930
#
#            windspeed        casual    registered           cnt    day_type  \
# count   17379.000000  17379.000000  17379.000000  17379.000000       17379
# unique           NaN           NaN           NaN           NaN           2
# top              NaN           NaN           NaN           NaN  Hari Kerja
# freq             NaN           NaN           NaN           NaN       11865
# mean        0.190098     35.676218    153.786869    189.463088         NaN
# min         0.000000      0.000000      0.000000      1.000000         NaN
# 25%         0.104500      4.000000     34.000000     40.000000         NaN
# 50%         0.194000     17.000000    115.000000    142.000000         NaN
# 75%         0.253700     48.000000    220.000000    281.000000         NaN
# max         0.850700    367.000000    886.000000    977.000000         NaN
# std         0.122340     49.305030    151.357286    181.387599         NaN
#
#                 year         month
# count   17379.000000  17379.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean     2011.502561      6.537775
# min      2011.000000      1.000000
# 25%      2011.000000      4.000000
# 50%      2012.000000      7.000000
# 75%      2012.000000     10.000000
# max      2012.000000     12.000000
# std         0.500008      3.438776

# %%
hour_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17374    False
# 17375    False
# 17376    False
# 17377    False
# 17378    False
# Length: 17379, dtype: bool

# %% [markdown]
# ### Univariate & Bivariate EDA

# %% [markdown]
# #### Deskripsi Statistik

# %%
sns.set_theme(style="whitegrid")

print("Deskripsi Statistik Data Harian:")
display(day_df.describe())
# Out:
# Deskripsi Statistik Data Harian:
#                               dteday            yr          mnth  \
# count                          17379  17379.000000  17379.000000
# mean   2012-01-02 04:08:34.552045568      0.502561      6.537775
# min              2011-01-01 00:00:00      0.000000      1.000000
# 25%              2011-07-04 00:00:00      0.000000      4.000000
# 50%              2012-01-02 00:00:00      1.000000      7.000000
# 75%              2012-07-02 00:00:00      1.000000     10.000000
# max              2012-12-31 00:00:00      1.000000     12.000000
# std                              NaN      0.500008      3.438776
#
#                  hr       holiday    workingday          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean      11.546752      0.028770      0.682721      0.496987      0.475775
# min        0.000000      0.000000      0.000000      0.020000      0.000000
# 25%        6.000000      0.000000      0.000000      0.340000      0.333300
# 50%       12.000000      0.000000      1.000000      0.500000      0.484800
# 75%       18.000000      0.000000      1.000000      0.660000      0.621200
# max       23.000000      1.000000      1.000000      1.000000      1.000000
# std        6.914405      0.167165      0.465431      0.192556      0.171850
#
#                 hum     windspeed        casual    registered           cnt  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098     35.676218    153.786869    189.463088
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        0.780000      0.253700     48.000000    220.000000    281.000000
# max        1.000000      0.850700    367.000000    886.000000    977.000000
# std        0.192930      0.122340     49.305030    151.357286    181.387599
#
#                year         month
# count  17379.000000  17379.000000
# mean    2011.502561      6.537775
# min     2011.000000      1.000000
# 25%     2011.000000      4.000000
# 50%     2012.000000      7.000000
# 75%     2012.000000     10.000000
# max     2012.000000     12.000000
# std        0.500008      3.438776

# %% [markdown]
# **Insight**
# - Dari deskripsi statistik terlihat bahwa rata-rata penyewaan harian (cnt ≈ 189) dengan median lebih rendah (142) menunjukkan distribusi cenderung right-skewed (ada beberapa hari dengan lonjakan tinggi), didukung oleh nilai maksimum yang jauh lebih besar (977); selain itu, kontribusi registered jauh lebih dominan dibanding casual, serta variasi (std cukup besar) menandakan fluktuasi permintaan yang signifikan antar hari.

# %% [markdown]
# #### Visualisasi Distribusi Data (Univariate)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(day_df['cnt'], bins=30, kde=True, color='skyblue')
plt.title('Distribusi Total Penyewaan Sepeda Harian (cnt)')
plt.xlabel('Jumlah Penyewaan')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight**
# - Distribusi penyewaan harian terlihat miring ke kanan (right-skewed), di mana sebagian besar hari memiliki jumlah penyewaan rendah–menengah, namun terdapat sedikit hari dengan penyewaan sangat tinggi (ekor panjang ke kanan), yang menunjukkan adanya lonjakan permintaan pada waktu tertentu.

# %% [markdown]
# #### Pengecekan Outlier berdasarkan Musim (Bivariate)

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(
    x='season',
    y='cnt',
    data=day_df,
    hue='season',
    palette='Set2',
    legend=False
)

plt.title('Distribusi Penyewaan Sepeda Berdasarkan Musim (Cek Outlier)')
plt.xlabel('Musim (1: Spring, 2: Summer, 3: Fall, 4: Winter)')
plt.ylabel('Total Penyewaan (cnt)')
plt.show()

# %% [markdown]
# **Insight**
# - Dari boxplot terlihat bahwa **median penyewaan tertinggi ada di Fall, diikuti Summer**, dengan **sebaran (variabilitas) yang lebih lebar** dibanding musim lain, sementara Spring paling rendah; selain itu, banyak **outlier di semua musim** menandakan adanya hari-hari dengan lonjakan penyewaan yang tidak biasa.

# %% [markdown]
# ### EDA Pertanyaan Nomor 1 (Tren MoM 2011 vs 2012)

# %%
monthly_rentals_df = day_df.groupby(by=['year', 'month']).agg({
    'cnt': 'sum',
    'registered': 'sum',
    'casual': 'sum'
}).reset_index()

monthly_rentals_df['year_label'] = monthly_rentals_df['year'].apply(lambda x: '2011' if x == 0 else '2012')

print("Tabel Agregasi Penyewaan Bulanan (Tren MoM):")
display(monthly_rentals_df.head(10))
# Out:
# Tabel Agregasi Penyewaan Bulanan (Tren MoM):
#    year  month     cnt  registered  casual year_label
# 0  2011      1   38189       35116    3073       2012
# 1  2011      2   48215       41973    6242       2012
# 2  2011      3   64045       51219   12826       2012
# 3  2011      4   94870       72524   22346       2012
# 4  2011      5  135821      104771   31050       2012
# 5  2011      6  143512      112900   30612       2012
# 6  2011      7  141341      104889   36452       2012
# 7  2011      8  136691      107849   28842       2012
# 8  2011      9  127418      100873   26545       2012
# 9  2011     10  123511       98289   25222       2012

# %% [markdown]
# **Insight**
# - Tren penyewaan bulanan menunjukkan peningkatan dari awal tahun hingga puncak di pertengahan tahun (sekitar Juni–Juli), lalu menurun hingga akhir tahun, dengan pola yang konsisten dan volume tahun 2012 yang lebih tinggi dibanding 2011; artinya, terdapat pertumbuhan positif sehingga penambahan armada sebaiknya difokuskan menjelang periode puncak.

# %% [markdown]
# ### EDA Pertanyaan Nomor 2 (Rush Hour Hari Kerja Q4 2012)

# %%
q4_2012_workdays = hour_df[(hour_df['year'] == 2012) & 
                           (hour_df['month'].isin([10, 11, 12])) & 
                           (hour_df['workingday'] == 1)]

rush_hour_df = q4_2012_workdays.groupby(by='hr').agg({
    'cnt': 'mean',
    'registered': 'mean',
    'casual': 'mean'
}).reset_index()

rush_hour_sorted = rush_hour_df.sort_values(by='cnt', ascending=False)

print("Tabel Agregasi Rata-rata Penyewaan per Jam (Hari Kerja Q4 2012):")
display(rush_hour_sorted.head())
# Out:
# Tabel Agregasi Rata-rata Penyewaan per Jam (Hari Kerja Q4 2012):
#     hr         cnt  registered     casual
# 17  17  618.639344  567.540984  51.098361
# 8    8  614.316667  596.100000  18.216667
# 18  18  547.032787  512.721311  34.311475
# 16  16  382.311475  330.836066  51.475410
# 19  19  374.016393  348.606557  25.409836

# %% [markdown]
# **Insight**
# - Berdasarkan hasil agregasi data, puncak rata-rata volume penyewaan sepeda (rush hour) pada hari kerja selama Q4 2012 terjadi pada jam 17.00 dengan jumlah tertinggi (≈618 penyewaan), diikuti oleh jam 08.00 dan jam 18.00, yang menunjukkan pola mobilitas pengguna saat berangkat dan pulang kerja; oleh karena itu, untuk menghindari gangguan terhadap pelanggan, jadwal maintenance sebaiknya tidak dilakukan pada jam-jam tersebut dan lebih ideal ditempatkan pada periode dengan aktivitas lebih rendah seperti siang hari atau setelah malam hari.

# %% [markdown]
# ### Agregasi rata-rata penyewaan berdasarkan kondisi cuaca

# %%
weather_impact_df = day_df.groupby(by='weathersit').agg({
    'cnt': ['mean', 'max', 'min', 'count']
}).reset_index()

print("Tabel Dampak Cuaca Terhadap Penyewaan:")
display(weather_impact_df)
# Out:
# Tabel Dampak Cuaca Terhadap Penyewaan:
#                weathersit         cnt
#                                  mean  max min  count
# 0  Cerah/Sebagian Berawan  204.869272  977   1  11413
# 1       Hujan Lebat/Badai   74.333333  164  23      3
# 2           Kabut/Berawan  175.165493  957   1   4544
# 3      Salju Ringan/Hujan  111.579281  891   1   1419

# %% [markdown]
# ### Pengaruh Musim terhadap Jumlah Pengguna (Bar Chart)

# %%
plt.figure(figsize=(8, 5))
season_order = day_df.groupby('season')['cnt'].mean().sort_values(ascending=False).index

sns.barplot(
    data=day_df, x='season', y='cnt', order=season_order, hue='season',     
    palette='viridis', errorbar=None, legend=False          
)

plt.title('Rata-rata Jumlah Pengguna Berdasarkan Musim', fontsize=14)
plt.xlabel('Musim', fontsize=12)
plt.ylabel('Rata-rata Pengguna Harian', fontsize=12)

plt.show()

# %% [markdown]
# ### Pengaruh Kondisi Cuaca terhadap Jumlah Pengguna (Boxplot)

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(data=day_df, x='weathersit', y='cnt', palette='Set2', hue='weathersit', legend=False)
plt.title('Distribusi Jumlah Pengguna Berdasarkan Kondisi Cuaca', fontsize=14)
plt.xlabel('Kondisi Cuaca', fontsize=12)
plt.ylabel('Total Pengguna (cnt)', fontsize=12)
plt.show()

# %% [markdown]
# **Insight:**
# - Rata-rata penyewaan sepeda tertinggi terjadi pada musim Fall, diikuti Summer dan Winter, sementara Spring paling rendah, menunjukkan bahwa penggunaan cenderung meningkat pada musim dengan cuaca lebih nyaman dan stabil, serta menurun pada musim yang kurang mendukung aktivitas bersepeda.
# - Boxplot menunjukkan bahwa jumlah pengguna sepeda paling tinggi dan variatif terjadi saat cuaca cerah/berawan, menurun pada kondisi berkabut/berawan, semakin rendah saat hujan ringan/salju, dan paling sedikit saat hujan lebat/badai; ini menegaskan bahwa semakin buruk kondisi cuaca, semakin rendah minat pengguna untuk menyewa sepeda.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana tren pertumbuhan total penyewaan sepeda secara bulanan (Month-over-Month) sepanjang tahun 2012 jika dibandingkan dengan tahun 2011, guna merencanakan target penambahan kapasitas armada sepeda di tahun depan?

# %%
sns.set_theme(style="whitegrid")
monthly_trend = day_df.groupby(['year', 'month'])['cnt'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_trend, x='month', y='cnt', hue='year', marker='o', palette='Set1', linewidth=2.5)
plt.title('Pertanyaan 1: Tren Pertumbuhan Penyewaan Sepeda Bulanan (2011 vs 2012)', fontsize=14, fontweight='bold')
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Total Penyewaan (cnt)', fontsize=12)
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'Mei', 'Jun', 'Jul', 'Ags', 'Sep', 'Okt', 'Nov', 'Des'])
plt.legend(title='Tahun')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Pada jam berapakah rata-rata volume penyewaan sepeda mencapai puncaknya (rush hour) khusus pada hari kerja (workingday) selama Kuartal ke-4 (Bulan Oktober - Desember) tahun 2012, agar tim operasional dapat menetapkan jadwal maintenance rutin tanpa mengganggu pelanggan?

# %%
q4_2012_workdays = hour_df[(hour_df['year'] == 2012) & 
                           (hour_df['month'].isin([10, 11, 12])) & 
                           (hour_df['workingday'] == 1)]

hourly_q4 = q4_2012_workdays.groupby('hr')['cnt'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=hourly_q4, x='hr', y='cnt', color='#4C72B0')
plt.title('Pertanyaan 2: Rata-rata Penyewaan per Jam (Hari Kerja - Q4 2012)', fontsize=14, fontweight='bold')
plt.xlabel('Jam Dalam Sehari (00:00 - 23:00)', fontsize=12)
plt.ylabel('Rata-rata Penyewaan', fontsize=12)
plt.xticks(range(0, 24))
plt.show()

# %% [markdown]
# **Insight:**
# - Tren Bulanan Penyewaan Sepeda (2011 vs 2012):
# Jumlah penyewaan sepeda pada tahun 2012 selalu lebih tinggi dibandingkan tahun 2011 di setiap bulan. Kedua tahun menunjukkan pola musiman yang serupa, yaitu permintaan rendah pada awal tahun, meningkat secara bertahap hingga mencapai puncak pada bulan Agustus–September, kemudian kembali menurun menjelang akhir tahun.
# - Pola Jam Sibuk pada Hari Kerja Q4 2012
# Penyewaan sepeda pada hari kerja membentuk pola bimodal dengan dua puncak utama, yaitu pada pukul 08.00 pagi serta pukul 17.00–18.00 sore. Sebaliknya, aktivitas penyewaan berada pada titik terendah pada rentang tengah malam hingga dini hari.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ### Metode yang Digunakan: Clustering (Binning)

# %%
day_df['demand_category'] = pd.qcut(day_df['cnt'], q=3, labels=['Low Demand', 'Medium Demand', 'High Demand'])

high_demand_days = day_df[day_df['demand_category'] == 'High Demand']
weather_on_high_demand = high_demand_days['weathersit'].value_counts().reset_index()
weather_on_high_demand.columns = ['weathersit', 'total_days']

print("Karakteristik Cuaca saat High Demand:")
print(weather_on_high_demand)
# Out:
# Karakteristik Cuaca saat High Demand:
#                weathersit  total_days
# 0  Cerah/Sebagian Berawan        4188
# 1           Kabut/Berawan        1361
# 2      Salju Ringan/Hujan         210

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
demand_counts = day_df['demand_category'].value_counts()
plt.pie(demand_counts, labels=demand_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99'], startangle=90)
plt.title('Proporsi Kategori Permintaan Harian', fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Proporsi Kategori Permintaan Harian')

# %%
plt.subplot(1, 2, 2)
sns.boxplot(data=day_df, x='demand_category', y='temp', palette='coolwarm',hue='demand_category', legend=False)
plt.title('Sebaran Suhu (Temperature) di Setiap Kategori Permintaan', fontsize=14, fontweight='bold')
plt.xlabel('Kategori Permintaan', fontsize=12)
plt.ylabel('Suhu yang Dinormalisasi', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Pembagian kategori menggunakan metode clustering (binning) menghasilkan distribusi data yang seimbang antara Low, Medium, dan High Demand sehingga analisis menjadi lebih representatif dan tidak condong ke satu kelompok tertentu
# - Hasil pengelompokan menunjukkan bahwa cuaca dan suhu berpengaruh terhadap permintaan, di mana kategori High Demand lebih sering terjadi saat cuaca cerah dan suhu lebih tinggi
# - Clustering membantu menyederhanakan data permintaan yang awalnya berupa angka menjadi kategori yang lebih mudah dipahami sehingga pola perilaku pengguna dapat terlihat dengan lebih jelas

# %% [markdown]
# ### Menyimpan Data

# %%
day_df.to_csv("final_cleaned_day.csv", index=False)
hour_df.to_csv("final_cleaned_hour.csv", index=False)

print("Data berhasil disimpan!")
print("file 'final_cleaned_day.csv' dan 'final_cleaned_hour.csv' sudah tersimpan")
# Out:
# Data berhasil disimpan!
# file 'final_cleaned_day.csv' dan 'final_cleaned_hour.csv' sudah tersimpan

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1:
# Bisnis penyewaan sepeda menunjukkan pertumbuhan yang signifikan dari tahun 2011 ke 2012 dengan pola permintaan musiman yang konsisten, di mana penyewaan mencapai puncak pada pertengahan tahun dan menurun pada awal serta akhir tahun. Oleh karena itu, perusahaan perlu menyiapkan penambahan serta distribusi armada sebelum memasuki musim puncak, terutama pada bulan April atau Mei, serta menjalankan program promosi khusus pada periode permintaan rendah untuk menjaga stabilitas pendapatan sepanjang tahun.
# - Conclution pertanyaan 2:
# Pola penyewaan pada hari kerja menunjukkan bahwa sepeda lebih banyak dimanfaatkan sebagai sarana transportasi komuter, ditandai dengan lonjakan permintaan pada pagi hari serta sore hari saat jam berangkat dan pulang kerja. Untuk mendukung kebutuhan tersebut, aktivitas pemeliharaan dan redistribusi sepeda sebaiknya dilakukan di luar jam sibuk, khususnya pada malam hingga dini hari, serta menambah staf operasional pada jam puncak agar ketersediaan unit dan kualitas layanan tetap terjaga.
